# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../sample_data/cars.csv')
df.head()
# Out:
#      brand  km_driven    fuel         owner  selling_price
# 0   Maruti     145500  Diesel   First Owner         450000
# 1    Skoda     120000  Diesel  Second Owner         370000
# 2    Honda     140000  Petrol   Third Owner         158000
# 3  Hyundai     127000  Diesel   First Owner         225000
# 4   Maruti     120000  Petrol   First Owner         130000

# %%
df.sample(10)
# Out:
#           brand  km_driven    fuel                 owner  selling_price
# 97      Hyundai      72000  Petrol           First Owner         565000
# 2433   Mahindra     110000  Diesel          Second Owner         650000
# 5031     Maruti      15381  Diesel           First Owner         800000
# 5618      Volvo      20000  Diesel           First Owner        3800000
# 1892     Maruti      70000  Petrol  Fourth & Above Owner         150000
# 2696    Hyundai      70000  Petrol           Third Owner         170000
# 7463       Ford      43011  Petrol           First Owner         550000
# 5380    Hyundai      80000  Petrol          Second Owner         650000
# 4206  Chevrolet      99500  Diesel           Third Owner         500000
# 1212     Maruti      70000  Petrol          Second Owner         650000

# %%
df['brand'].value_counts()
# Out:
# brand
# Maruti           2448
# Hyundai          1415
# Mahindra          772
# Tata              734
# Toyota            488
# Honda             467
# Ford              397
# Chevrolet         230
# Renault           228
# Volkswagen        186
# BMW               120
# Skoda             105
# Nissan             81
# Jaguar             71
# Volvo              67
# Datsun             65
# Mercedes-Benz      54
# Fiat               47
# Audi               40
# Lexus              34
# Jeep               31
# Mitsubishi         14
# Force               6
# Land                6
# Isuzu               5
# Kia                 4
# Ambassador          4
# Daewoo              3
# MG                  3
# Ashok               1
# Opel                1
# Peugeot             1
# Name: count, dtype: int64

# %%
df['brand'].nunique()
# Out:
# 32

# %%
df['fuel'].value_counts()
# Out:
# fuel
# Diesel    4402
# Petrol    3631
# CNG         57
# LPG         38
# Name: count, dtype: int64

# %%
df['owner'].value_counts()
# Out:
# owner
# First Owner             5289
# Second Owner            2105
# Third Owner              555
# Fourth & Above Owner     174
# Test Drive Car             5
# Name: count, dtype: int64

# %%
pd.get_dummies(df,columns=['fuel','owner'],dtype=int)
# Out:
#         brand  km_driven  selling_price  fuel_CNG  fuel_Diesel  fuel_LPG  \
# 0      Maruti     145500         450000         0            1         0
# 1       Skoda     120000         370000         0            1         0
# 2       Honda     140000         158000         0            0         0
# 3     Hyundai     127000         225000         0            1         0
# 4      Maruti     120000         130000         0            0         0
# ...       ...        ...            ...       ...          ...       ...
# 8123  Hyundai     110000         320000         0            0         0
# 8124  Hyundai     119000         135000         0            1         0
# 8125   Maruti     120000         382000         0            1         0
# 8126     Tata      25000         290000         0            1         0
# 8127     Tata      25000         290000         0            1         0
#
#       fuel_Petrol  owner_First Owner  owner_Fourth & Above Owner  \
# ...

# %% [markdown]
# k-1 onehot encoding

# %%
pd.get_dummies(df,columns=['fuel','owner'],dtype=int,drop_first=True)
# Out:
#         brand  km_driven  selling_price  fuel_Diesel  fuel_LPG  fuel_Petrol  \
# 0      Maruti     145500         450000            1         0            0
# 1       Skoda     120000         370000            1         0            0
# 2       Honda     140000         158000            0         0            1
# 3     Hyundai     127000         225000            1         0            0
# 4      Maruti     120000         130000            0         0            1
# ...       ...        ...            ...          ...       ...          ...
# 8123  Hyundai     110000         320000            0         0            1
# 8124  Hyundai     119000         135000            1         0            0
# 8125   Maruti     120000         382000            1         0            0
# 8126     Tata      25000         290000            1         0            0
# 8127     Tata      25000         290000            1         0            0
#
# ...

# %% [markdown]
# one hot encoding using scikit learn

# %%
x = df.drop('selling_price',axis=1)
y = df['selling_price']
x
# Out:
#         brand  km_driven    fuel                 owner
# 0      Maruti     145500  Diesel           First Owner
# 1       Skoda     120000  Diesel          Second Owner
# 2       Honda     140000  Petrol           Third Owner
# 3     Hyundai     127000  Diesel           First Owner
# 4      Maruti     120000  Petrol           First Owner
# ...       ...        ...     ...                   ...
# 8123  Hyundai     110000  Petrol           First Owner
# 8124  Hyundai     119000  Diesel  Fourth & Above Owner
# 8125   Maruti     120000  Diesel           First Owner
# 8126     Tata      25000  Diesel           First Owner
# 8127     Tata      25000  Diesel           First Owner
#
# [8128 rows x 4 columns]

# %%
y
# Out:
# 0       450000
# 1       370000
# 2       158000
# 3       225000
# 4       130000
#          ...
# 8123    320000
# 8124    135000
# 8125    382000
# 8126    290000
# 8127    290000
# Name: selling_price, Length: 8128, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
df.head()
# Out:
#      brand  km_driven    fuel         owner  selling_price
# 0   Maruti     145500  Diesel   First Owner         450000
# 1    Skoda     120000  Diesel  Second Owner         370000
# 2    Honda     140000  Petrol   Third Owner         158000
# 3  Hyundai     127000  Diesel   First Owner         225000
# 4   Maruti     120000  Petrol   First Owner         130000

# %%
x_train.head()
# Out:
#         brand  km_driven    fuel                 owner
# 6518     Tata       2560  Petrol           First Owner
# 6144    Honda      80000  Petrol          Second Owner
# 6381  Hyundai     150000  Diesel  Fourth & Above Owner
# 438    Maruti     120000  Diesel          Second Owner
# 5939   Maruti      25000  Petrol           First Owner

# %%
# from sklearn.preprocessing import OneHotEncoder
# ohe = OneHotEncoder()
# x_train_new = ohe.fit_transform(x_train[['fuel','owner']]).toarray()

# %%
# np.hstack((x_train[['brand','km_driven']].values,x_train_new))

# %%
from sklearn.preprocessing import OneHotEncoder
import numpy as np

ohe = OneHotEncoder(drop='first', sparse_output=False, dtype=np.int32)

# Train
x_train_cat = ohe.fit_transform(x_train[['fuel','owner']])
x_train_final = np.hstack((
    x_train[['km_driven']].values,
    x_train_cat
))

# Test
x_test_cat = ohe.transform(x_test[['fuel','owner']])
x_test_final = np.hstack((
    x_test[['km_driven']].values,
    x_test_cat
))

# %%
brand_counts = df['brand'].value_counts()

# %%
threshhold = 100

# %%
df['brand'].nunique()
# Out:
# 32

# %%
replace = brand_counts[brand_counts<=threshhold].index

# %%
replace
# Out:
# Index(['Nissan', 'Jaguar', 'Volvo', 'Datsun', 'Mercedes-Benz', 'Fiat', 'Audi',
#        'Lexus', 'Jeep', 'Mitsubishi', 'Force', 'Land', 'Isuzu', 'Kia',
#        'Ambassador', 'Daewoo', 'MG', 'Ashok', 'Opel', 'Peugeot'],
#       dtype='object', name='brand')

# %%
df['brand'].value_counts()
# Out:
# brand
# Maruti           2448
# Hyundai          1415
# Mahindra          772
# Tata              734
# Toyota            488
# Honda             467
# Ford              397
# Chevrolet         230
# Renault           228
# Volkswagen        186
# BMW               120
# Skoda             105
# Nissan             81
# Jaguar             71
# Volvo              67
# Datsun             65
# Mercedes-Benz      54
# Fiat               47
# Audi               40
# Lexus              34
# Jeep               31
# Mitsubishi         14
# Force               6
# Land                6
# Isuzu               5
# Kia                 4
# Ambassador          4
# Daewoo              3
# MG                  3
# Ashok               1
# Opel                1
# Peugeot             1
# Name: count, dtype: int64

# %%
pd.get_dummies(df['brand'].replace(brand_counts,'uncommon'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/sg/x59phjgd28b4zgd29ltjhgp40000gn/T/ipykernel_47425/114791589.py in ?()
# ----> 1 pd.get_dummies(df['brand'].replace(brand_counts,'uncommon'))
#
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, to_replace, value, inplace, limit, regex, method)
#    8098                 # {'A': NA} -> 0
#    8099                 elif not is_list_like(value):
#    8100                     # Operate column-wise
#    8101                     if self.ndim == 1:
# -> 8102                         raise ValueError(
#    8103                             "Series.replace cannot use dict-like to_replace "
#    8104                             "and non-None value"
#    8105                         )
#
# ValueError: Series.replace cannot use dict-like to_replace and non-None value
