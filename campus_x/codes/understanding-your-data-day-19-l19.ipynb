# %%
import pandas as pd

# %%
df = pd.read_csv('../sample_data/train.csv')

# %% [markdown]
# 1.HOW BIG IS DATA

# %%
df.shape

# %% [markdown]
# 2.HOW DOES THE DATA LOK LIKE?

# %%
df.head()

# %% [markdown]
# if you feel there is baisness in the data  in starting some rows u can use sample to see random data

# %%
df.sample(5)

# %% [markdown]
# 3.WHAT IS THE DATA TYPE OF COLS?

# %%
df.info()

# %% [markdown]
# 4.ARE THERE ANY MISSING VALUES?

# %%
df.isnull().sum()

# %% [markdown]
# 5.HOW DOES THE DATA LOOK MATHEMATICALLY?

# %%
df.describe()

# %% [markdown]
# 6.ARE THERE DUPLICATE VALUES?

# %%
df.duplicated().sum()

# %% [markdown]
# 7.HOW IS THE CORRELATION BETWEEN COLS?

# %%
# df.corr()not working maybe worked in past versions 
df.corr(numeric_only=True)
